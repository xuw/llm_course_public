# %% [markdown]
# ## 5.4  Optional: text to video with T2V
# We take a text-to-video model for example.
# Use the pre-downloaded model weights on `/share/lab5/t2v`, or make sure you have downloaded the weights of it:

# %%
#!export HF_ENDPOINT=https://hf-mirror.com
#!huggingface-cli download --resume-download damo-vilab/text-to-video-ms-1.7b  --local-dir your_path_of_t2v

# %%
# Install the requirements, and you should RESTART the kernel after completing the installation.
# !pip install opencv-python
# !apt-get install libgl1 -y

# %%
import torch
from diffusers import DiffusionPipeline
from diffusers.utils import export_to_video

pipe = DiffusionPipeline.from_pretrained("/share/lab5/t2v", torch_dtype=torch.float16, variant="fp16")
pipe = pipe.to("cuda")

# %%
prompt = "Darth Vader riding a electric bike in the forest.\n"
video_frames_list = pipe(prompt,num_inference_steps=40, num_frames=100).frames
output_video_path = "/scratch2/darth_video.mp4"
video_path = export_to_video(video_frames=video_frames_list[0], output_video_path=output_video_path, fps=10)
video_path

# %%
prompt = "A happy mickey mouse dancing on a tower.\n"
video_frames_list = pipe(prompt,num_inference_steps=40, num_frames=100).frames
output_video_path = "/scratch2/mickey_video.mp4"
video_path = export_to_video(video_frames=video_frames_list[0], output_video_path=output_video_path, fps=10)
video_path

# %% [markdown]
# The above code will display the save path of the output video, and the current encoding format can be played with **VLC player**. You can download the video and view it using VLC media player. Some other media players may not view it normally.

# %%
#### Your Task ####
# feel free to play with the model, and share any interesting findings.  But you do not have to submit anything for this task.
